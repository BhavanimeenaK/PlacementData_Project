# %% [markdown]
# **Analysing a placement dataset:**

# %% [markdown]
# #Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
df=pd.read_csv("/drive/My Drive/Datasets/Placement_Data.csv")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# **First four rows of the dataframe:**

# %%
df.head(4)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN

# %% [markdown]
# **Getting the feature names:**

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %% [markdown]
# **Number of records and columns:**

# %%
df.shape
# Out:
# (215, 15)

# %% [markdown]
# **Number of records:**

# %%
df.shape[0]
# Out:
# 215

# %% [markdown]
# **Number of features:**

# %%
df.shape[1]
# Out:
# 15

# %% [markdown]
# **Number of null entries and the datatypes of the features:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# **The Average Secondary Education Percentage:**

# %%
df["ssc_p"].mean()
# Out:
# 67.30339534883721

# %% [markdown]
# **The Maximum Seconadary Education Percentage:**

# %%
df["ssc_p"].max()
# Out:
# 89.4

# %% [markdown]
# **Is the 10th topper placed?**

# %%
df[df["ssc_p"]==df["ssc_p"].max()]["status"]
# Out:
# 145    Placed
# Name: status, dtype: object

# %% [markdown]
# **The Maximum Higher Secondary Education Percentage:**

# %%
df["hsc_p"].max()
# Out:
# 97.7

# %% [markdown]
# **Is the 12th grade topper placed?**

# %%
df[df["hsc_p"]==df["hsc_p"].max()]["status"]
# Out:
# 24    Placed
# Name: status, dtype: object

# %% [markdown]
# **Number of students placed and not placed:**

# %%
df["status"].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %% [markdown]
# **Degrees vs Placement:**

# %%
df[df["status"]=="Placed"]["degree_t"].value_counts()
# Out:
# Comm&Mgmt    102
# Sci&Tech      41
# Others         5
# Name: degree_t, dtype: int64

# %% [markdown]
# *The most commom degree of the placed students is Commerce and Management.*

# %% [markdown]
# **Number of unique degrees in the dataset:**

# %%
df["degree_t"].nunique()
# Out:
# 3

# %% [markdown]
# **Correlation of the features**

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# # Data Preprocessing

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# **Number of null values in each features:**

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# *The salary has 67 null values because of the not placed students.*

# %% [markdown]
# **Filling the null values of the salaries with appropriate value (i.e.,0):**

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# *Now the null values of the salaries are filled with zeros.*

# %% [markdown]
# # Data Visualizati on

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Scatter plot between ssc_p and hsc_p:**

# %%
plt.scatter(df["ssc_p"],df["hsc_p"])
plt.xlabel("10th percentage marks")
plt.ylabel("12th percentage marks")
plt.title("Scatter plot of 10th and 12th percentage of the students:")
# Out:
# Text(0.5, 1.0, 'Scatter plot of 10th and 12th percentage of the students:')

# %% [markdown]
# **The scatter plot between 10th and 12th percentage of the students grouped based on the placement status:**

# %%
colors={"Placed":"tab:green","Not Placed":"tab:red"}

# %%
plt.scatter(df["ssc_p"],df["hsc_p"],c=df["status"].map(colors))

# %% [markdown]
# **Pairplot between all the continuous columns based on the status:**

# %%
sns.pairplot(df,hue="status")

# %% [markdown]
# **Boxplot for 10th percentage of the students:"**

# %%
sns.boxplot(y="ssc_p",data=df)
# Out:
# <Axes: ylabel='ssc_p'>

# %% [markdown]
# **Boxplot for 12th percentage of the students:**

# %%
sns.boxplot(y="hsc_p",data=df)
# Out:
# <Axes: ylabel='hsc_p'>

# %% [markdown]
# **Lineplot for 10th and 12th percentage:**

# %%
plt.plot(df["ssc_p"],label="10th percentage")
plt.plot(df["hsc_p"],label="12th percentage")
plt.legend()

# %% [markdown]
# **Heatmap of the correlation matrix:**

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-37-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# **Histogram for the salary of the students:**

# %%
plt.hist(df["salary"])
# Out:
# (array([67.,  0., 94., 38., 10.,  3.,  1.,  1.,  0.,  1.]),
#  array([     0.,  94000., 188000., 282000., 376000., 470000., 564000.,
#         658000., 752000., 846000., 940000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Distributon of the salary of the students:**

# %%
sns.kdeplot(df["salary"])
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %% [markdown]
# #Again Data Preprocessing

# %% [markdown]
# **Outlier Analysis:**

# %%
col=["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]

# %%
for c in col:
  plt.figure()
  sns.boxplot(y=c,data=df)

# %%
col=["hsc_p","degree_p","salary"]

# %%
for c in col:
  plt.figure()
  sns.boxplot(y=c, data=df)
  percentile25=df[c].quantile(0.25)
  percentile75=df[c].quantile(0.75)
  iqr=percentile75-percentile25
  upper_limit=percentile75+(1.5*iqr)
  lower_limit=percentile25-(1.5*iqr)
  df=df[(df[c]<=upper_limit) & (df[c]>=lower_limit)]
  plt.figure()
  sns.boxplot(y=c,data=df)

# %% [markdown]
# *The outliers has been removed.*

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
col=["gender","ssc_b","hsc_b","hsc_s","degree_t","workex","specialisation","status"]

# %%
for c in col:
  df[c]=le.fit_transform(df[c])

# %%
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1  67.00      1  91.00      1      1     58.00         2
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status    salary
# ...

# %% [markdown]
# *=> Thus label Encoded.*

# %% [markdown]
# # Linear Regression

# %%
X=df.iloc[:,0:-1].values

# %%
Y=df.iloc[:,-1].values

# %% [markdown]
# **Splitting the training and testing data:**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=25)

# %% [markdown]
# **Standardizing the features:**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
#  **The Linear Regression model:**

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=reg.predict(X_test)

# %%
Y_pred
# Out:
# array([265941.94334192, 241452.91078717, 278748.47787212,  24805.16526726,
#        312541.02328004, 314190.48979307, 296024.27955089, 328194.42449381,
#         22474.61630551,  41520.12520273, 299901.02404978, -17635.80581336,
#        313700.36750881,  -6778.99008766,   8409.88269005, 323257.70136206,
#        272841.51201964, 257707.60239637, 288719.57381321,  49903.16281195,
#         72430.58412898,  98573.11458698, 329705.9789624 , 342557.30900704,
#        270698.89029704, 329703.3312804 ,  38056.4041532 , 261128.92225186,
#        -31082.29962495, 259332.79472018,   5135.51716195,  93384.14786431,
#        277925.38176814, 286802.54696903, 272702.48627105,  44367.52885901,
#        309670.10368387, 338662.68886862,  15137.71102266, 285091.07607469,
#        277662.22857048, 297354.13494083, 288290.42360851,  15138.58529859,
#        248983.15177044, 234310.62572419, 239220.33578937, 269653.51716117,
# ...

# %% [markdown]
# **Evaluation:**

# %%
from sklearn import metrics

# %%
# Mean squared error:
metrics.mean_squared_error(Y_test,Y_pred)
# Out:
# 2683979880.7935824

# %%
# Root mean squared error
np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))
# Out:
# 51807.14121425329

# %%
#R squared score
metrics.r2_score(Y_test,Y_pred)
# Out:
# 0.8695452869966817

# %% [markdown]
# # Logistic Regression model

# %% [markdown]
# **Extracting independent and dependent variables:**

# %%
X=df.drop(["status"],axis=1).values
Y=df["status"].values

# %% [markdown]
# **Spltting training and testing data:**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=27)

# %% [markdown]
# **Standardization:**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# **The Logistic Regression model:**

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=classifier.predict(X_test)

# %% [markdown]
# **Evaluation of the LogisticRegression model:**

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,Y_pred)
# Out:
# array([[20,  0],
#        [ 0, 42]])

# %%
# Accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 1.0

# %%
# ROC AUC score
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,Y_pred)
# Out:
# 1.0

# %%
# Classifcation report
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        42
#
#     accuracy                           1.00        62
#    macro avg       1.00      1.00      1.00        62
# weighted avg       1.00      1.00      1.00        62

# %% [markdown]
# # Clustering

# %% [markdown]
# **Selecting the number of cluster:**

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(6)

# %% [markdown]
# **Standardization:**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(df)
# Out:
# array([[-1.71499859,  0.73576721, -0.04854299, ..., -0.60020802,
#          0.65845762,  0.51777428],
#        [-1.69884761,  0.73576721,  1.11371606, ...,  0.70561763,
#          0.65845762,  0.02535855],
#        [-1.68269662,  0.73576721, -0.23706838, ..., -0.77478364,
#          0.65845762,  0.37708407],
#        ...,
#        [ 1.70901091,  0.73576721, -0.04854299, ...,  1.30615777,
#          0.65845762,  0.69363704],
#        [ 1.7251619 , -1.35912554,  0.61129589, ..., -0.35056488,
#          0.65845762,  0.05349659],
#        [ 1.74131289,  0.73576721, -0.51985647, ..., -0.35231064,
#         -1.51870063, -1.38154353]])

# %%
scaled_df=pd.DataFrame(sc.fit_transform(df),columns=df.columns)

# %% [markdown]
# **Building the model:**

# %%
kmeans.fit(scaled_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=6)

# %%
kmeans.predict(scaled_df)
# Out:
# array([1, 0, 5, 4, 5, 4, 2, 0, 5, 2, 5, 5, 2, 5, 4, 5, 5, 2, 2, 3, 1, 3,
#        0, 0, 2, 3, 1, 3, 2, 5, 2, 5, 3, 4, 5, 4, 0, 1, 0, 3, 2, 3, 3, 2,
#        2, 5, 1, 5, 4, 4, 0, 1, 1, 1, 5, 1, 0, 5, 5, 0, 4, 3, 4, 1, 3, 2,
#        0, 0, 3, 3, 5, 5, 2, 5, 0, 0, 2, 1, 3, 2, 0, 0, 3, 1, 4, 5, 0, 3,
#        4, 5, 4, 5, 3, 5, 2, 5, 2, 4, 5, 3, 0, 1, 4, 4, 3, 5, 4, 0, 4, 1,
#        3, 1, 3, 5, 0, 0, 0, 5, 1, 0, 5, 0, 1, 0, 3, 2, 0, 1, 1, 1, 2, 1,
#        0, 5, 1, 4, 0, 3, 4, 0, 1, 5, 5, 4, 0, 5, 0, 0, 1, 4, 0, 5, 4, 4,
#        0, 4, 3, 0, 5, 2, 1, 0, 4, 2, 3, 1, 4, 0, 4, 1, 0, 2, 1, 4, 4, 5,
#        4, 0, 2, 0, 4, 2, 2, 1, 5, 5, 4, 5, 0, 2, 1, 1, 4, 0, 1, 3, 1, 3,
#        4, 5, 3, 0, 3, 1, 4], dtype=int32)

# %%
kmeans.inertia_
# Out:
# 1875.9197537964906

# %% [markdown]
# **Elbow Method to find the optimal number of clusters:**

# %%
inertia=[]
for i in range(1,11):
  print(i)
  kmeans=KMeans(i)
  kmeans.fit(scaled_df)
  print(kmeans.inertia_)
  inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 1
# 3074.999999999999
# 2
# 2506.7194356052514
# ...

# %%
Number_of_clusters=range(1,11)

# %%
plt.plot(Number_of_clusters,inertia,marker="o")
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title("Elbow curve")
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# *From the graph,the optimum number of cluster is 3.*

# %%
kmean=KMeans(3)
kmeans.fit(scaled_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=10)

# %%
kmeans.predict(scaled_df)
# Out:
# array([3, 1, 6, 9, 6, 5, 8, 1, 6, 9, 6, 6, 8, 6, 9, 6, 6, 8, 8, 2, 3, 2,
#        7, 4, 0, 2, 3, 2, 9, 6, 8, 6, 2, 5, 6, 9, 7, 7, 4, 2, 8, 2, 2, 8,
#        8, 6, 3, 7, 9, 0, 4, 7, 3, 2, 6, 3, 3, 1, 6, 4, 0, 2, 5, 7, 2, 8,
#        1, 4, 2, 2, 2, 6, 8, 6, 4, 4, 8, 7, 4, 9, 4, 1, 2, 3, 9, 6, 7, 2,
#        9, 6, 9, 6, 2, 1, 8, 6, 5, 0, 6, 2, 1, 3, 5, 5, 2, 6, 5, 7, 5, 3,
#        2, 3, 4, 6, 4, 1, 1, 6, 3, 1, 6, 4, 7, 1, 2, 9, 4, 3, 3, 7, 0, 3,
#        4, 6, 3, 9, 1, 2, 0, 4, 3, 6, 6, 0, 1, 6, 4, 4, 3, 0, 1, 6, 5, 0,
#        1, 0, 2, 4, 6, 8, 3, 5, 0, 0, 2, 3, 5, 4, 5, 3, 4, 8, 3, 5, 0, 6,
#        0, 1, 0, 1, 0, 8, 0, 3, 6, 6, 0, 6, 4, 8, 3, 3, 5, 1, 3, 2, 3, 2,
#        8, 6, 2, 4, 2, 7, 5], dtype=int32)

# %%
pd.DataFrame(kmeans.predict(scaled_df))
# Out:
#      0
# 0    3
# 1    1
# 2    6
# 3    9
# 4    6
# ..  ..
# 200  2
# 201  4
# 202  2
# 203  7
# 204  5
#
# [205 rows x 1 columns]

# %% [markdown]
# #Principle Component Analysis

# %% [markdown]
# **Dropping the target columns:**

# %%
new_df=df.drop(columns=["status","salary"],axis=1)

# %% [markdown]
# **Standardization:**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(new_df)
# Out:
# array([[-1.71499859,  0.73576721, -0.04854299, ..., -1.28939008,
#          1.11926192, -0.60020802],
#        [-1.69884761,  0.73576721,  1.11371606, ...,  1.12278123,
#         -0.89344592,  0.70561763],
#        [-1.68269662,  0.73576721, -0.23706838, ...,  0.24214726,
#         -0.89344592, -0.77478364],
#        ...,
#        [ 1.70901091,  0.73576721, -0.04854299, ..., -0.98308261,
#         -0.89344592,  1.30615777],
#        [ 1.7251619 , -1.35912554,  0.61129589, ..., -0.14073707,
#          1.11926192, -0.35056488],
#        [ 1.74131289,  0.73576721, -0.51985647, ...,  1.31422339,
#          1.11926192, -0.35231064]])

# %% [markdown]
# **Tranforming data into Principle Components:**

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=5)
pca_array=pca.fit_transform(sc.fit_transform(new_df))

# %% [markdown]
# **Percentage of data in each Principle Components:**

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2029994 , 0.14476223, 0.11878368, 0.10058381, 0.07952812])

# %% [markdown]
# *The first PC contains 20%, the second PC contains 14%,the third PC contains 11%,the fourth PC contains 10%,the fifth PC contains 7% of information.*

# %% [markdown]
# **Total Percentage of data in all the Principle Components:**

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.6466572255303695

# %% [markdown]
# *The final PCA contains 64% of information.*

# %% [markdown]
# **DataFrame of Principle Components:**

# %%
pca_df=pd.DataFrame(pca_array,columns=["PC1","PC2","PC3","PC4","PC5"])

# %%
pca_df["status"]=df.reset_index()["status"]
pca_df["salary"]=df.reset_index()["salary"]

# %%
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PC1     205 non-null    float64
#  1   PC2     205 non-null    float64
#  2   PC3     205 non-null    float64
#  3   PC4     205 non-null    float64
#  4   PC5     205 non-null    float64
#  5   status  205 non-null    int64
#  6   salary  205 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 11.3 KB

# %% [markdown]
# **Linear Regression model after PCA:**

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression

# %%
X=pca_df.iloc[:,0:-1].values
Y=df["salary"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)

# %%
from sklearn import metrics
metrics.r2_score(Y_test, Y_pred)
# Out:
# 0.77431682455845

# %% [markdown]
# Thank you.
